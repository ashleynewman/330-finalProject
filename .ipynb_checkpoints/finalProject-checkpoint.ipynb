# %% [markdown]
# ## Final Project Code
# - by: Ashley Newman (submitted to GitHub), Christopher Gamboa, and Sophie Loesberg

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import json
import os
import requests
import re
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
from bs4 import BeautifulSoup
import requests
import numpy as np
from scipy.stats import pearsonr
import scipy.stats as stats

# %% [markdown]
# **Setting Up/Reading in the Data**

# %%
def read_streaming_platforms_data():
    #convert csv file to dataframe and return the dataframe
    df = pd.read_csv('MoviesOnStreamingPlatforms_updated.csv')
    return df

# %%
#calling the function and setting it to a variable stremaing_df
streaming_df = read_streaming_platforms_data()

#switch year column to be string objects
streaming_df['Year'] = streaming_df['Year'].astype(str)

#switch rotten tomatoes column to be string objects
streaming_df['Rotten Tomatoes'] = streaming_df['Rotten Tomatoes'].astype(str)

#swicth imdb column to be float
streaming_df['IMDb'] = streaming_df['IMDb'].astype(float)

streaming_df.head()
# Out:
#        Unnamed: 0     ID                      Title  Year  Age  IMDb  \
# 16739       16739  16740  The Ghosts of Buxley Hall  1980  NaN   6.2
# 16740       16740  16741             The Poof Point  2001   7+   4.7
# 16741       16741  16742      Sharks of Lost Island  2013  NaN   5.7
# 16742       16742  16743         Man Among Cheetahs  2017  NaN   6.6
# 16743       16743  16744           In Beaver Valley  1950  NaN   NaN
#
#       Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 16739             nan        0     0            0        1     0
# 16740             nan        0     0            0        1     0
# 16741             nan        0     0            0        1     0
# 16742             nan        0     0            0        1     0
# 16743             nan        0     0            0        1     0
#
#                   Directors                        Genres        Country  \
# 16739          Bruce Bilson  Comedy,Family,Fantasy,Horror  United States
# ...

# %%
def beautiful_soup_imdb():
    #get the website into BeautifulSoup 
    r = requests.get('https://www.imdb.com/chart/moviemeter/?sort=ir,desc&mode=simple&page=1')
    soup = BeautifulSoup(r.text, 'html.parser')
    
    #grabbing the IMDB table
    x = soup.find('table', class_ = 'chart full-width')
    body = x.find('tbody', class_='lister-list')

    #grabbing the necessary rows inside the IMDB table
    titles = body.find_all('td', class_='titleColumn')
    ratings = body.find_all('td', class_='ratingColumn imdbRating')
    year = body.find_all('td', class_='ratingColumn imdbRating')

    #creating lists to pass this data into
    titles_list = []
    ratings_list = []
    year_list = []

    #passing the data from the Beautiful Soup into the lists
    for i in titles:
        temp = i.find('a').text
        titles_list.append(temp)
        year = str(i.find('span', class_='secondaryInfo').text)[1:-1]
        year_list.append(year)
    for i in ratings:
        temp = str(i.find('strong'))
        
        if temp != 'None':
            ratings_list.append(temp[-12:-9])
        else:
            ratings_list.append(np.nan)
    
    #return the lists so they can be read into a dataframe
    return titles_list, ratings_list, year_list

# %%
def read_imdb_website_data():
    #call the Beautiful Soup function
    titles_list, ratings_list, year_list = beautiful_soup_imdb()

    #read the lists into a dictionary
    data = {'Title': titles_list, 'Year': year_list, 'IMDb': ratings_list}

    #create a dataframe of the lists and return the dataframe
    df = pd.DataFrame(data, columns = ['Title', 'Year', 'IMDb'])
    return df

imdb_df = read_imdb_website_data()
#convert ratings to floats
imdb_df['IMDb'] = imdb_df['IMDb'].astype(float)
imdb_df.head()
# Out:
#                       Title  Year  IMDb
# 95                  Cruella  2021   NaN
# 96               The Batman  2022   NaN
# 97  Spider-Man: No Way Home  2021   NaN
# 98   Thor: Love and Thunder  2022   NaN
# 99  Space Jam: A New Legacy  2021   NaN

# %% [markdown]
# **Editing the Data Types**

# %%
def convert_years(df):
    #convert dataframe year column to datetime format
    df['Year'] = pd.to_datetime(df['Year'])
    
    return df

#convert years for streaming_df
streaming_df2 = convert_years(streaming_df)
display(streaming_df2.head())

#convert years for imdb_df
imdb_df2 = convert_years(imdb_df)
display(imdb_df2.head())
# Out:
#    Unnamed: 0  ID                           Title       Year  Age  IMDb  \
# 0           0   1                       Inception 2010-01-01  13+   8.8
# 1           1   2                      The Matrix 1999-01-01  18+   8.7
# 2           2   3          Avengers: Infinity War 2018-01-01  13+   8.5
# 3           3   4              Back to the Future 1985-01-01   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly 1966-01-01  18+   8.8
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# 2             84%        1     0            0        0     0
# 3             96%        1     0            0        0     0
# 4             97%        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %%
#function to convert percentage string to a float score out of 10
def make_num(x):
    num = x[:-1]
    try:
        return float(num) / 10.0
    except:
        return float(np.nan)

    
# convert the rotten tomatoes column in streaming_df to a score out of 10 instead of a percentage
def convert_rotten_tomatoes_to_score(df):
    df['Rotten Tomatoes'] = df['Rotten Tomatoes'].apply(make_num)
    return df


streaming_df3 = convert_rotten_tomatoes_to_score(streaming_df2)
streaming_df3.head()
# Out:
#    Unnamed: 0  ID                           Title       Year  Age  IMDb  \
# 0           0   1                       Inception 2010-01-01  13+   8.8
# 1           1   2                      The Matrix 1999-01-01  18+   8.7
# 2           2   3          Avengers: Infinity War 2018-01-01  13+   8.5
# 3           3   4              Back to the Future 1985-01-01   7+   8.5
# 4           4   5  The Good, the Bad and the Ugly 1966-01-01  18+   8.8
#
#    Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0              8.7        1     0            0        0     0
# 1              8.7        1     0            0        0     0
# 2              8.4        1     0            0        0     0
# 3              9.6        1     0            0        0     0
# 4              9.7        1     0            1        0     0
#
#                         Directors                            Genres  \
# 0               Christopher Nolan  Action,Adventure,Sci-Fi,Thriller
# ...

# %% [markdown]
# **Statistical Analysis**

# %%
def statistical_analysis(df1, df2):
    #imdb rating series
    rating = df1['IMDb']
    rating = rating.dropna()
#     print(len(rating))

    #streaming rotten tomatoes series
    tomato = df2['Rotten Tomatoes']
    tomato = tomato.dropna()
#     print(len(tomato))
    
    #making lengths the same for series (for each time function is called)
    if len(rating) == 87:
        tomato = tomato[:87]
        
    elif len(tomato) == 5158:
        rating = rating[:5158]
        
    #correlation analysis
    corr, _ = pearsonr(rating, tomato)
    
    print('Pearsons correlation: %.3f' % corr)
    

    
#How are IMDb rating and rotten tomatoes score related?
statistical_analysis(imdb_df2, streaming_df3)

#how are IMDB rating and rotten tomatoes score related in regard to same file?
#anticorrelated b/c negative
statistical_analysis(streaming_df3, streaming_df3)
# Out:
# Pearsons correlation: 0.284
# Pearsons correlation: -0.068

# %%
def statistical_analysis2(x, y):
    #tells us whether 2 data samples have different means
    x = x.dropna()
    y = y.dropna()
    
    print(stats.ttest_ind(a=x, b=y, equal_var=False))
    
    
#t-test for checking for IMDb means in each dataframe and if they are different or not for means
statistical_analysis2(imdb_df2['IMDb'], streaming_df3['IMDb'])

#t-test for IMDb vs rotten tomato in streaming df to see if they are different or not for means
statistical_analysis2(streaming_df3['IMDb'], streaming_df3['Rotten Tomatoes'])
# Out:
# Ttest_indResult(statistic=6.885613265895784, pvalue=8.540882417333001e-10)
# Ttest_indResult(statistic=-16.607078759571497, pvalue=1.3566754335582972e-60)

# %% [markdown]
# **Data Manipulation with Pandas and Numpy**

# %%
def calculations(imdb, stream):
    #combine dataframes
    df = stream.append(imdb, ignore_index=True)
    df = df.set_index('Year', drop=True)
    
    #pivot table of data
    table = pd.pivot_table(df, values='IMDb', index=['Netflix', 'Hulu', 'Prime Video', 'Disney+'], columns=['Title'], aggfunc=np.mean)
    display(table)
    
    #which streaming service has the most movies per decade
    n = 0
    h = 0
    d = 0
    ap = 0
    for group, frame in df.groupby([(df.index.year//10)*10, "Netflix", "Hulu", "Prime Video", "Disney+"]):
        if group[1] == 1.0:
            n += 1
        if group[2] == 1.0:
            h += 1
        if group[3] == 1.0:
            ap += 1
        if group[4] == 1.0:
            d += 1
    print('netflix:' + str(n), 'hulu:' + str(h), 'primeVideo:' + str(ap), 'disney+:' + str(d))
    
    #which year has the highest average rating for movies
    grouped_df = df.groupby("Year")
    mean_df = grouped_df['IMDb'].mean().sort_values(ascending=False)
    print(mean_df)
    
    #which year has the highest rated movie
    g = df.groupby("Year")
    maxx = g[['IMDb', 'Title']].max().sort_values(by='IMDb', ascending=False)
    result = maxx[:5]
    lst = []
    count = 0
    for i in result.index.values:
        lst.append(i.astype(str)[0:4] + ': ' + maxx.iloc[count]['Title'])
        count += 1
    print('The years that have the highest rates movies are: ', lst, 'at a rating of ', result.iloc[0][0])
    return df

    
    
df = calculations(imdb_df2, streaming_df3)
# Out:
# /opt/conda/lib/python3.7/site-packages/pandas/core/frame.py:7116: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   sort=sort,
# Title                             #IMomSoHard Live  #LoveSwag  #Rucker50  \
# Netflix Hulu Prime Video Disney+
# 0.0     0.0  0.0         1.0                   NaN        NaN        NaN
#              1.0         0.0                   5.2        5.4        NaN
#                          1.0                   NaN        NaN        NaN
#         1.0  0.0         0.0                   NaN        NaN        NaN
#                          1.0                   NaN        NaN        NaN
#              1.0         0.0                   NaN        NaN        NaN
#                          1.0                   NaN        NaN        NaN
# ...

# %% [markdown]
# **Visualizations and Calculations**

# %%
def scatterplot_of_imdb_ratings(df):
    df = df.reset_index()

    x = df['Year']
    y = df["IMDb"]
    
    plt.scatter(x, y, color='#32db84')
    plt.xlabel("Years")
    plt.ylabel("IMDb Ratings")
    plt.title("IMDb Ratings for Each Movie")
    plt.show()

#all IMDb ratings for each movie in the combined dataframe
scatterplot_of_imdb_ratings(df)

# %%
def new_vis(df):
    df = df.reset_index()
    group = df.groupby('Year').agg(np.mean)
    x = group.index.get_level_values(0)
    y = group['IMDb']
    
    plt.scatter(x, y)
    plt.xlabel("Years")
    plt.ylabel("Average IMDb Ratings")
    plt.title("Average IMDb Ratings for Each Year")
    plt.show()

#Average rating for movies each year (scatterplot)    
new_vis(df)

# %%
def same_movie_percentage(df1,df2):
    #Makes a dataframe that has matching movie titles 
    merged_df=df1.merge(df2, how= 'inner', on = ['Title'])
    
    #Finds the total number of movies in the dataframe
    total_number_of_movies = len(merged_df.index)
    
    #Finds the number of movies for each streaming service and calcluates the total percentage
    netflix_total = merged_df['Netflix'].sum()/total_number_of_movies*100
    hulu_total = merged_df['Hulu'].sum()/total_number_of_movies*100
    prime_video_total = merged_df['Prime Video'].sum()/total_number_of_movies*100
    disney_total = merged_df['Disney+'].sum()/total_number_of_movies*100

    #creates a pie chart based off of each streaming services percentage
    pie_chart=np.array([disney_total,prime_video_total,hulu_total,netflix_total])
    pie_labels = ["Disney+","Prime Video","Hulu","Netflix"]
    plt.pie(pie_chart, labels = pie_labels, autopct='%1.1f%%')
    plt.show()
    
#pie graph of percentage of movies on each streaming platform   
same_movie_percentage(imdb_df2, streaming_df3)

# %%
def fresh_score(df1,df2):
    #This only looks at data in streaming_df3
    
    # Rotten Tomatoes website marks anything above a 60% as fresh
    
    #claculating the scores to get averages and counts of rotten tomatoes scores above a 60% for Netflix
    netflix_avg_score_above_60 = df2[df2['Rotten Tomatoes']>=6.0].groupby('Netflix').agg({'Rotten Tomatoes':np.nanmean})
    netflix_above_60_count = df2[df2['Rotten Tomatoes']>=6.0].groupby('Netflix')['Rotten Tomatoes'].count()
    netflix_avg_score_above_60 = netflix_avg_score_above_60.iloc[1][0]
    netflix_above_60_count = netflix_above_60_count.iloc[1] 
    print(netflix_avg_score_above_60)
    print(netflix_above_60_count)
    
    #claculating the scores to get averages and counts of rotten tomatoes scores above a 60% for Hulu
    hulu_avg_score_above_60 = df2[df2['Rotten Tomatoes']>=6.0].groupby('Hulu').agg({'Rotten Tomatoes':np.nanmean})
    hulu_above_60_count = df2[df2['Rotten Tomatoes']>=6.0].groupby('Hulu')['Rotten Tomatoes'].count()
    hulu_avg_score_above_60 = hulu_avg_score_above_60.iloc[1][0]
    hulu_above_60_count = hulu_above_60_count.iloc[1] 
    print(hulu_avg_score_above_60)
    print(hulu_above_60_count)
    
    #claculating the scores to get averages and counts of rotten tomatoes scores above a 60% for Prime Video
    prime_avg_score_above_60 = df2[df2['Rotten Tomatoes']>=6.0].groupby('Prime Video').agg({'Rotten Tomatoes':np.nanmean})
    prime_above_60_count = df2[df2['Rotten Tomatoes']>=6.0].groupby('Prime Video')['Rotten Tomatoes'].count()
    prime_avg_score_above_60 = prime_avg_score_above_60.iloc[1][0]
    prime_above_60_count = prime_above_60_count.iloc[1] 
    print(prime_avg_score_above_60)
    print(prime_above_60_count)
    
    #claculating the scores to get averages and counts of rotten tomatoes scores above a 60% for Disney+
    disney_avg_score_above_60 = df2[df2['Rotten Tomatoes']>=6.0].groupby('Disney+').agg({'Rotten Tomatoes':np.nanmean})
    disney_above_60_count = df2[df2['Rotten Tomatoes']>=6.0].groupby('Disney+')['Rotten Tomatoes'].count()
    disney_avg_score_above_60 = disney_avg_score_above_60.iloc[1][0]
    disney_above_60_count = disney_above_60_count.iloc[1] 
    print(disney_avg_score_above_60)
    print(disney_above_60_count)
    
    
    #setting up data for graph 1
    data = {'Netflix':netflix_avg_score_above_60,'Hulu':hulu_avg_score_above_60,'Prime Video':prime_avg_score_above_60,'Disney+':disney_avg_score_above_60}
    streaming_service = list(data.keys())
    average_score = list(data.values())
    
    #creating graph 1 (average rotten tomato score for each platform > 60%)
    fig = plt.figure(figsize = (10,5))
    
    plt.bar(streaming_service,average_score,color=['red','green','orange','blue'])
    plt.xlabel("Stream Services")
    plt.ylabel("Average Score")
    plt.title("Average Score Rated 60% or Higher")
    plt.show()
    
    #setting up data for graph 2
    data = {'Netflix':netflix_above_60_count,'Hulu':hulu_above_60_count,'Prime Video':prime_above_60_count,'Disney+':disney_above_60_count}
    streaming_service = list(data.keys())
    average_score = list(data.values())

    #creating graph 2 (number of movies on each platform > 60%)
    fig = plt.figure(figsize = (10,5))
    
    plt.bar(streaming_service,average_score,color=['red','green','orange','blue'])
    plt.xlabel("Stream Services")
    plt.ylabel("Number of Movies")
    plt.title("Number of Movies Rated 60% or Higher")
    plt.show()
    
fresh_score(imdb_df2, streaming_df3)
# Out:
# 8.385082872928194
# 905
# 8.32553191489362
# 423
# 8.284396415392724
# 1897
# 8.238571428571426
# 210

# %% [markdown]
# **Data Manipulation with SQL**

# %%
# %%capture
#setting up the sql databases of our two dataframes
# %load_ext sql
# %sql postgres://jovyan:si330studentuser@localhost:5432/si330
# %sql drop table if exists imdb
# %sql drop table if exists streaming


import sqlalchemy
engine = sqlalchemy.create_engine('postgres://jovyan:si330studentuser@localhost:5432/si330')

imdb_df2.to_sql("imdb",engine)
streaming_df3.to_sql("streaming",engine)

# %%
# %%sql
# --editing the streaming table to make all column titles one word each
# ALTER TABLE "streaming"
# rename "Prime Video" to "PrimeVideo";
#
# ALTER TABLE "streaming"
# rename "Disney+" to "DisneyPlus";
# Out:
#  * postgres://jovyan:***@localhost:5432/si330
# Done.
# Done.
# []

# %%
# %%sql
# --creating average movie ratings for each platform table and inserting the averages into the first row
#
# drop table if exists movie_avg;
# create table movie_avg (
#     " " varchar(255),
#     "Netflix" float,
#     "Hulu" float,
#     "PrimeVideo" float,
#     "DisneyPlus" float
# );
# insert into movie_avg values (
#     ('average_movie_ratings:'),
#     (select avg("IMDb") from streaming where "Netflix" = 1),
#     (select avg("IMDb") from streaming where "Hulu" = 1),
#     (select avg("IMDb") from streaming where "PrimeVideo" = 1),
#     (select avg("IMDb") from streaming where "DisneyPlus" = 1)
# );
# select * from movie_avg;
# Out:
#  * postgres://jovyan:***@localhost:5432/si330
# Done.
# Done.
# 1 rows affected.
# 1 rows affected.
# [('average_movie_ratings:', 6.25296339337595, 6.13811659192825, 5.77091031239501, 6.44138543516873)]

# %%
# %%sql
# --calculating the number of movies on each platform for the data where titles are the same in each sql table
#
# select sum(combo."Netflix") as "num_netflix", sum(combo."Hulu") as "num_hulu",
# sum(combo."PrimeVideo") as "num_prime", sum(combo."DisneyPlus") as "num_disney"
# from (streaming inner join imdb on streaming."Title" = imdb."Title") as combo;
# Out:
#  * postgres://jovyan:***@localhost:5432/si330
# 1 rows affected.
# [(Decimal('6'), Decimal('2'), Decimal('8'), Decimal('3'))]

# %%
# %%sql
# --calculating percentage of number of movies on each platform in a new table
#
# drop table if exists platform_percentages;
# create table platform_percentages (
#     " " varchar(255),
#     "Netflix" float,
#     "Hulu" float,
#     "PrimeVideo" float,
#     "DisneyPlus" float
# );
# insert into platform_percentages values (
#     ('platform_percentages_for_imdb_movies:'),
#     (SELECT
#   (SELECT sum("Netflix") FROM streaming) /
#   (SELECT count("ID") FROM streaming)),
#     (SELECT
#   (SELECT sum("Hulu") FROM streaming) /
#   (SELECT count("ID") FROM streaming)),
#     (SELECT
#   (SELECT sum("PrimeVideo") FROM streaming) /
#   (SELECT count("ID") FROM streaming)),
#     (SELECT
#   (SELECT sum("DisneyPlus") FROM streaming) /
#   (SELECT count("ID") FROM streaming))
# );
#
# select * from platform_percentages;
# Out:
#  * postgres://jovyan:***@localhost:5432/si330
# Done.
# Done.
# 1 rows affected.
# 1 rows affected.
# [('platform_percentages_for_imdb_movies:', 0.212613473483039, 0.0539297658862876, 0.737816531294792, 0.0336837075967511)]

# %%
# %%sql
# --extra calulation to observe movies with release dates before 1930
#
# select * from streaming where "Year" < '1930-01-01 00:00:00';
# Out:
#  * postgres://jovyan:***@localhost:5432/si330
# 54 rows affected.
# [(3774, 3774, 3775, 'The Hunchback of Notre Dame', datetime.datetime(1923, 1, 1, 0, 0), None, 7.3, 9.1, 0, 1, 0, 1, 0, 'Gary Trousdale,Kirk Wise', 'Animation,Drama,Family,Musical,Romance', 'United States,France', 'English,Latin', 91.0),
#  (4467, 4467, 4468, 'A Trip to the Moon', datetime.datetime(1902, 1, 1, 0, 0), 'all', 8.2, 10.0, 0, 0, 1, 0, 0, 'Georges Méliès', 'Short,Action,Adventure,Comedy,Fantasy,Sci-Fi', 'France', 'None,French', 13.0),
#  (4468, 4468, 4469, 'The General', datetime.datetime(1926, 1, 1, 0, 0), None, 8.1, 9.3, 0, 0, 1, 0, 0, 'Clyde Bruckman,Buster Keaton', 'Action,Adventure,Comedy,Drama,War', 'United States', 'English', 67.0),
#  (4469, 4469, 4470, 'Nosferatu', datetime.datetime(1922, 1, 1, 0, 0), None, 7.9, 9.7, 0, 0, 1, 0, 0, None, 'Drama,Fantasy,Horror,Mystery', 'United States', 'English', 60.0),
# ...

# %% [markdown]
# ## Test Cases

# %%
def test_read_streaming_platforms_data():
    assert streaming_df['ID'].dtypes == int
    assert streaming_df['Title'].loc[0] == 'Inception'
    assert len(streaming_df['Directors'].unique() == 11339)

test_read_streaming_platforms_data()

# %%
def test_read_imdb_website_data():
    assert imdb_df.iloc[1][0] == 'The Godfather'
    assert imdb_df.iloc[2][2] == 9.0
    assert len(imdb_df.loc[1]) == len(imdb_df.loc[0])
    
    assert len(imdb_df['Year'].unique()) == 18
    assert imdb_df.iloc[1][2] == 9.2
    assert isinstance(imdb_df.iloc[1][2], float)
    assert imdb_df['IMDb'].dtypes == float

test_read_imdb_website_data()

# %%
import datetime
def test_convert_years():
    assert isinstance(streaming_df2.loc[0]['Year'], datetime.datetime)
    assert isinstance(imdb_df2.loc[0]['Year'], datetime.datetime)
    assert imdb_df2.loc[4]['Year'] == pd.to_datetime('2001-01-01 00:00:00')
   
    
test_convert_years()

# %%
def test_convert_rotten_tomatoes_to_score():
    assert streaming_df3['Rotten Tomatoes'][0] == 8.7
    assert streaming_df3['Rotten Tomatoes'][3] == 9.6
    assert streaming_df3['Rotten Tomatoes'].dtypes == float
    
    
test_convert_rotten_tomatoes_to_score()

# %%
import datetime
def test_calculations(imdb, stream):
    df = stream.append(imdb, ignore_index=True)
    df = df.set_index('Year', drop=True)
    
    table = pd.pivot_table(df, values='IMDb', index=['Netflix', 'Hulu', 'Prime Video', 'Disney+'], columns=['Title'], aggfunc=np.mean)
    assert len(table) == 14
    
    x = df.groupby([(df.index.year//10)*10, "Netflix", "Hulu", "Prime Video", "Disney+"])
    assert len(x) == 178
    
    grouped_df = df.groupby("Year")
    mean_df = grouped_df['IMDb'].mean().sort_values(ascending=False)
    assert len(mean_df) == 111
    assert mean_df[0] == 6.069565217391304
    
    g = df.groupby("Year")
    maxx = g[['IMDb', 'Title']].max().sort_values(by='IMDb', ascending=False)
    assert len(maxx) == 111
    result = maxx[:5]
    assert len(result.index.values) == 5

    
test_calculations(imdb_df2, streaming_df3)

# %%
def test_new_vis(df):
    assert len(df.groupby('Year').agg(np.mean)) == 111
    assert len(df.groupby('Year').agg(np.mean).columns) == 10
    assert df.groupby('Year').agg(np.mean).columns[0] == 'Disney+'
    
    
test_new_vis(df)

# %%
def test_same_movie_percentage(df1, df2):
    merged_df=df1.merge(df2, how= 'inner', on = ['Title'])
    total_number_of_movies = len(merged_df.index)
    netflix_total = merged_df['Netflix'].sum()/total_number_of_movies*100
    
    assert len(merged_df) == 17
    assert isinstance(netflix_total, float)
    assert netflix_total == 35.294117647058826
    
    
test_same_movie_percentage(imdb_df2, streaming_df3)

# %%
def test_fresh_score(df1, df2):
    hulu_avg_score_above_60 = df2[df2['Rotten Tomatoes']>=6.0].groupby('Hulu').agg({'Rotten Tomatoes':np.nanmean})
    hulu_above_60_count = df2[df2['Rotten Tomatoes']>=6.0].groupby('Hulu')['Rotten Tomatoes'].count()

    
    assert hulu_avg_score_above_60.loc[0]['Rotten Tomatoes'] == 8.311558854718983
    assert isinstance(hulu_avg_score_above_60.loc[0]['Rotten Tomatoes'], float)
    assert len(hulu_avg_score_above_60) == 2
    assert len(hulu_above_60_count) == 2
    assert isinstance(hulu_avg_score_above_60.loc[0]['Rotten Tomatoes'], float)
    
    hulu_avg_score_above_60 = hulu_avg_score_above_60.iloc[1][0]
    hulu_above_60_count = hulu_above_60_count.iloc[1] 
    
  
    assert hulu_avg_score_above_60 == 8.32553191489362
    assert isinstance(hulu_avg_score_above_60, float)
    assert hulu_above_60_count == 423
    
    
    
test_fresh_score(imdb_df2, streaming_df3)
